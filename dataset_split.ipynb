# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('application_train.csv')

# %%
y = df['TARGET']

# %%
X_train, X_dev, y_train, y_dev = train_test_split(df, y, test_size=0.2)

# %%
print(X_train.shape, y_train.shape)
print(X_dev.shape, y_dev.shape)
# Out:
# (246008, 122) (246008,)
# (61503, 122) (61503,)

# %%
#submit2.to_csv('random_forest_baseline.csv', index = False)

# %%
X_train.head()
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 15534       118129       0         Cash loans           F            Y
# 291457      437656       0         Cash loans           M            Y
# 187731      317631       1         Cash loans           F            N
# 66096       176655       0         Cash loans           F            N
# 35587       141216       0         Cash loans           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 15534                Y             0          157500.0    254700.0
# 291457               Y             1          180000.0   1051294.5
# 187731               Y             0           99000.0    343377.0
# 66096                Y             0          117000.0    346500.0
# 35587                N             0          270000.0    450000.0
#
#         AMT_ANNUITY  ...  FLAG_DOCUMENT_18 FLAG_DOCUMENT_19 FLAG_DOCUMENT_20  \
# 15534       15579.0  ...                 0                0                0
# 291457      30870.0  ...                 0                0                0
# 187731      11097.0  ...                 0                0                0
# 66096       14679.0  ...                 0                0                0
# 35587       35685.0  ...                 0                0                0
#
#        FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR AMT_REQ_CREDIT_BUREAU_DAY  \
# 15534                 0                        0.0                       0.0
# 291457                0                        0.0                       0.0
# 187731                0                        0.0                       0.0
# 66096                 0                        NaN                       NaN
# 35587                 0                        0.0                       0.0
#
#         AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# 15534                          0.0                        0.0
# 291457                         0.0                        0.0
# 187731                         0.0                        0.0
# 66096                          NaN                        NaN
# 35587                          0.0                        0.0
#
#         AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 15534                         0.0                         4.0
# 291457                        0.0                         1.0
# 187731                        1.0                         1.0
# 66096                         NaN                         NaN
# 35587                         0.0                         3.0
#
# [5 rows x 122 columns]

# %%
y_dev.head(10)
# Out:
# 114722    0
# 48115     0
# 19294     1
# 180037    0
# 162906    0
# 235745    0
# 51359     0
# 46103     0
# 188802    0
# 249921    0
# Name: TARGET, dtype: int64

# %%
X_dev.head()
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 114722      233029       0         Cash loans           F            N
# 48115       155722       0         Cash loans           M            N
# 19294       122508       1         Cash loans           M            N
# 180037      308638       0         Cash loans           F            Y
# 162906      288856       0         Cash loans           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 114722               N             0          135000.0    792346.5
# 48115                N             2          270000.0    755190.0
# 19294                Y             2          180000.0    512446.5
# 180037               N             0          112500.0   1078200.0
# 162906               Y             0          112500.0    113760.0
#
#         AMT_ANNUITY  ...  FLAG_DOCUMENT_18 FLAG_DOCUMENT_19 FLAG_DOCUMENT_20  \
# 114722      26185.5  ...                 0                0                0
# 48115       38686.5  ...                 0                0                0
# 19294       40486.5  ...                 0                0                0
# 180037      34911.0  ...                 0                0                0
# 162906       7533.0  ...                 0                0                0
#
#        FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR AMT_REQ_CREDIT_BUREAU_DAY  \
# 114722                0                        0.0                       0.0
# 48115                 0                        0.0                       1.0
# 19294                 0                        0.0                       0.0
# 180037                0                        0.0                       0.0
# 162906                0                        NaN                       NaN
#
#         AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# 114722                         0.0                        0.0
# 48115                          0.0                        0.0
# 19294                          1.0                        0.0
# 180037                         0.0                        0.0
# 162906                         NaN                        NaN
#
#         AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 114722                        0.0                         1.0
# 48115                         0.0                         4.0
# 19294                         1.0                         1.0
# 180037                        0.0                         0.0
# 162906                        NaN                         NaN
#
# [5 rows x 122 columns]

# %%
X_train.to_csv('X_train.csv', index = False)

# %%
y_train.to_csv('y_train.csv', index = False)

# %%
X_dev.to_csv('X_dev.csv', index = False)

# %%
y_dev.to_csv('y_dev.csv', index = False)
